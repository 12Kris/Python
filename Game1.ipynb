# %%
print("Ласкаво просимо у шоколадну фабрику Віллі Вонка!")
 # print('Запропоновані персонажі: Чарлі Бакетт, ')
# name=input("Оберіть персонажа: ")

selection = input("Оберіть персонажа: 1.Чарлі Бакетт 2. Агустус Глупць 3. Верука Солт 4. Майк Тіві")
match selection: 
    case "1": name = "Чарлі Бакетт"
    case "2": name = "Агустус Глупць"
    case "3": name = "Верука Солт"
    case "4": name = "Майк Тіві"

print(f"Вітаю! Ви обрали ім'я: {name}")

print("Ви одні з тих, хто знайшов золотий квиток, тому почнемо дивовижну подорож по шоколадній фабриці!")

print("1. Шоколадні ріки\n2. Карамельні човни\n")
selection = input("Оберіть місце, яке хотіли б відвідати:")
match selection: 
    case "1": 
        print("Ви обрали чудове місце ... \n Чи бажаєте ви стрибнути у шоколад\n1. Так\n2.Ні")
        selection = input("Введіть відповідь: ")
        match selection:
            case "1": 
                print("Ви стрибнули у річку, виявилось у шоколаді неможливо плавати. Ваші наступні дії:")
                print("1. Продовжити тонути\n2. Покликати на допомогу")
                selection = input("Введіть відповідь: ")
                match selection:
                    case "1":
                        print("Ви вмерли ситим. Алееее так як це світ чудес ви можете спостерігати і робити капості іншим, кому б ви хотіли дати пігулку, яка робить людину ГІГАНТООООМ?")
                        print("1. Віллі Вонка\n2. Гному охоронцю")
                        selection = input("Введіть відповідь: ")
                        match selection:
                            case "1":
                                print("у Вонки раптово виросли велитенські ноги, якими він почав душити учасників.")
                                print("1. Зупинити цю катастрофу\n2. Продовжити спостерігати")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Ви врятували життя людям, і за це вам Віллі Вонка вам дарує 100кг шоколаду з горішками")
                                    case "2":
                                        print("Вілі Вонка спочатку злякався, тому він проявив агресію. Але він вчасно зупинився і він почава допомагати учасникам")
                            case "2":
                                print("Гном розсердився, і вирішив зʼїсти шоколадку")
                                print("Яку шоколадку\n 1. Молочний щоколад\n 2. Чорний шоколад")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1": 
                                        print("Молочний шоколад зробив зробив його нормального розміру і він щасливий приступив до своєї роботи")
                                    case "2": 
                                        print("Гном не любить чорний шоколад та виплюнув його та заспокоївся")
                    
                    case "2": 
                        print("На допомогу поспішають гномики. Вони пропонують вам вибратись на човник, чи ви зможете це зробити? 1.Так\n2. Ні")
                        selection = input("Введіть відповідь: ")
                        match selection:
                            case "1":
                                print("Урааа! Ви змогли вилізти на цей маленький човен. Чи бажаєте ви мандрувати човником? 1.Так\n2. Ні")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Ви можете побачти всю фабрику і спробувати найсмачніший шоколад у Всесвіті!")
                                    case "2":
                                        print("Ви вибрались на сушу, тут вас чекали друзі. Ходімо розважатися у світі Солодощів")
            
                            case "2":
                                print("Можливо ви зможете схопитися за палицю Віллі Вонки? 1.Так\n2.Ні")   
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1": 
                                        print("Ви нарешті змогли вибратися з теплеснького шоколаду, гайда смакувати смачними карамельками")
                                    case "2":
                                        print("Нуууу вам було запропоновано багато варіантів вибратися, але ви не скористались жодним, нумо плисти по течії")
                            

            case "2":
               print("Ви залишились на поверхні. Чи бажаєте набрати кружечку гарячого шоколаду, прямо з річки?")
               print("1.Так, з радістю!\n2. Фууууу, нізащо!")
               selection = input("Введіть відповідь: ")
               match selection: 
                    case "1": 
                        print("Ви набираєте гарячого шоколаду і відчуваєте солодкий смак річкового шоколаду. Що ви будете робити далі?")
                        print("1. Продовжити подорож через ліс.\n2. Чи піти по морозиво?")
                        selection = input("Введіть відповідь: ")
                        match selection: 
                            case "1": 
                                print("Ви відпочили трохи і продовжили свою подорож через чарівний ліс. Чи бажаєте ви подивитися на Зіркову кімната шоколаду?")
                                print("1. Авжеш\n2. Нііііі")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Ви відкрили для себе дивовижні скульптури та фонтани із шоколаду.")
                                    case "2":
                                        print("Це найвища точка вашої подорожі, і ви насолоджуєтеся видом та ароматом шоколаду.")
                            case "2":
                                print("Морозиво було таке смачне, що ви вже не бажали повертатися. Можливо бажаєте повернутися додому?")
                                print("1. Так\n2. Ні")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Ви вирішили повернутися додому і попрощатися з чарівним світом, який вам довелося дослідити.")
                                    case "2":
                                        print("Ви вирішили залишитися ще трохи в цьому чудовому світі та досліджувати його далі.Ваша подорож продовжується, і вас чекають нові пригоди та враження.")  
                    case "2":
                        print("Ви відмовляєтеся від ідеї пити річковий шоколад і продовжуєте свою подорож, голодним. Чи бажаєте ви подивитися на крихітні будиночки з зефіру?")
                        print("1. Обожнюю зефір\n2. Ненавиджу зефір, навіть бачити його не хочу!")
                        selection = input("Введіть відповідь: ")
                        match selection: 
                            case "1": 
                                print("Ви вирішили подивитися на крихітні будиночки з зефіру. Можливо бажаєте скуштувати?")
                                print("1. Так, аж слюнки течуть так хочу сробувати\n2. Ні, я не голодний")
                                selection = input("Введіть відповідь: ")
                                match selection: 
                                    case "1": 
                                        print("Смак зефіру виявився надзвичайно солодким і ви спробували найкращий зефір у своєму житті..")
                                    case "2": 
                                        print("Ви не голодні і вирішили не скуштовувати зефірні будиночки.")
                            case "2":
                                print(" Не цікавитеся зефірними будиночками і без жодного зацікавлення продовжуєте свій шлях через ліс.можливо ви б хотіли піти пострибати на жиле?")
                                print("1. Так, давайте підемо стрибати на жиле!\n2. Ні я нудний і не люблю розваги")
                                selection = input("Введіть відповідь: ")
                                match selection: 
                                    case "1": 
                                        print("З кожним стрибком ви відчуваєте радість і насолоджуєтеся моментом.")
                                    case "2": 
                                        print("Ця подорож привела вас до багатьох незабутніх пригод та вражень, хоча ви зовсім не вмієте розважатися")
    case "2":
        print("Ви обрали чудове місце ... \n Чи бажаєте ви стрибнути у карамельний човер\n1. Так\n2.Ні")
        selection = input("Введіть відповідь: ")
        match selection:
            case "1": 
                print("Ви стрибнули у карамельний човен, виявилось у карамельному човні був отвір через який затікала кока-кола. Ваші наступні дії:")
                print("1. Тонути\n2. Взяти відерце та виливати колу за човен та намагатися врятуватися")
                selection = input("Введіть відповідь: ")
                match selection:
                    case "1":
                        print("Ви почали тонути та попали у підземний світ карамелі, де зустріли чарівника, який намагається вас убити")
                        print("1. Оборонятися\n2. Втікати")
                        selection = input("Введіть відповідь: ")
                        match selection:
                            case "1":
                                print("Ви перемогли чарівника, та забрали у нього чарівну мармеладну палицю.")
                                print("1. Спробувати використати цю палицю\n2. Піти далі")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Почавши чарувати палицею ви начарували собі смачної солодкої їжі, яку спробували та померли")
                                    case "2":
                                        print("Йдучи далі вам на голову упав великий шматок карамелі та ви померли")
                            case "2":
                                print("Втікаючи ви натрапили на шоколадного медведя, який просив вас допомоги")
                                print("1. Допомогти\n 2. Проігнорувати та йти далі")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1": 
                                        print("Допомагаючи медведю ви прийшли у його берлогу де він вас і зʼїв")
                                    case "2": 
                                        print("Коли ви почали рухатися далі медведь напав на вас зі спини та невдовзі ви померли")
                    

                    
                    case "2": 
                        print("Почавши викидувати виливати коку за човен на вас напало велике чудовисько з маршмелов")
                        print("1.Вистибнути з човна\n2. Залишитися у ньому") 
                        selection = input("Введіть відповідь: ")
                        match selection:
                            case "1":
                                print("Вистрибнувши з човна вам важко триматися на колі")
                                print("1.Атакувати чудовисько\n2. Втікати від нього")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Чудовисько виявилося сильнішим та убило вас")
                                    case "2":
                                        print("Ви не встигли та чудовисько зʼїло вас")
            
                            case "2":
                                print("Через те що ви трималися у човні чудовсько занирнуло під колу")  
                                print("1. Спробувати заткнути отвір у човні\n2. Спробувати далі викачувати воду з човна ") 
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1": 
                                        print("Поки ви заробляли отвір чудовсько зʼїло вас і ваш човен")
                                    case "2":
                                        print("Поки ви надалі викачували воду вас зʼїдо чудовисько разом з човном")
                            

            case "2":
               print("Ви залишилися на суші та думаєте чи потрібно вам йти у бухту човнів")
               print("1.Так!\n2. Краще піду до майстра карамельних човнів!")
               selection = input("Введіть відповідь: ")
               match selection: 
                    case "1": 
                        print("Йдучи у карамельну бухнуту на вас нападає вовк з білого шоколаду")
                        print("1. Втікати\n2. Атакувати")
                        selection = input("Введіть відповідь: ")
                        match selection: 
                            case "1": 
                                print("Втікаючи ви забігли у бухту де вас зустрів місцевий бандит")
                                print("1. Віддати бандитові все що у вас є\n2. Налякати бандита")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Віддавши все бандиту вас схопили та ви зникли...")
                                    case "2":
                                        print("Ви злякали бандита, але з переляку він вдарив вас ножем та ви померли")
                            case "2":
                                print("Ви відбили атаку вовка і почали втікати, але невдовзі прийшла його зграя")
                                print("1. Втікати лісом\n2. Втікати долиною")
                                selection = input("Введіть відповідь: ")
                                match selection:
                                    case "1":
                                        print("Втікаючи долиною вас наздогнали та зʼїли ")
                                    case "2":
                                        print("Втікаючи лісом ви вдарилися об дерево та вас наздогнали та зʼїли")  
                    case "2":
                        print("Йдучи до майстра корамельних човнів на вас натрпапив велетень")
                        print("1. Зʼїсти пігулку аби також стати велетнем\n2. Втікти у печеру")
                        selection = input("Введіть відповідь: ")
                        match selection: 
                            case "1": 
                                print("Ви зʼїли пігулку та стали також велетнем, але мешщим на нього")
                                print("1. Атакувати\n2. Шукати де можна сховатися")
                                selection = input("Введіть відповідь: ")
                                match selection: 
                                    case "1": 
                                        print("Ви його атакували, але він виявився сильнишим та убив вас")
                                    case "2": 
                                        print("Шукаючи місце, де прихиститися велетень випадково наступив на вас і ви помели")
                            case "2":
                                print("Ви втікли у печеру, але у печері на вас чекав неприємний сюрприз там сидів мармеладний дракон")
                                print("1. Спробувати сховатися від нього\n2. Вибігти з печери")
                                selection = input("Введіть відповідь: ")
                                match selection: 
                                    case "1": 
                                        print("Дракон вас помітив та піджарив вас та зʼїв")
                                    case "2": 
                                        print("У той час як ви втікали з печери на вас чекав велетень, який і забрав вас з собою...")
